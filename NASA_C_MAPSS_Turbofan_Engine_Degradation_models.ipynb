# %% [markdown]
# Cell 1 — Imports

# %% [markdown]
# Added transformer but there are already enough variations ask if that's still needed?

# %%
import zipfile
import random
import copy
import warnings
import math
from dataclasses import dataclass

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

warnings.filterwarnings("ignore")

# %% [markdown]
# Cell 2 — Config

# %%
@dataclass
class Config:
    zip_path: str = "CMAPSSData.zip"
    subset: str = "FD001"

    random_seed: int = 42
    train_ratio: float = 0.8

    batch_size: int = 128
    lr: float = 1e-3
    num_epochs: int = 100
    patience: int = 10
    weight_decay: float = 1e-5

    # LSTM baseline
    hidden_size: int = 128
    num_layers: int = 1
    lstm_dropout: float = 0.2

    # DCNN variant
    dcnn_num_filters: int = 32
    dcnn_fc_units: int = 100
    dcnn_dropout: float = 0.2

    window_size: int = 30
    rul_clip: int = 125


    device: str = "cuda" if torch.cuda.is_available() else "cpu"

CFG = Config()
print("Using device:", CFG.device)
# Out:
# Using device: cuda

# %% [markdown]
# Cell 3 — Seed

# %%
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(CFG.random_seed)

# %% [markdown]
# Cell 4 — Load Data

# %%
def get_zip_filenames(zip_path):
    with zipfile.ZipFile(zip_path, "r") as z:
        return z.namelist()

def resolve_member_path(zip_path, target_name):
    names = get_zip_filenames(zip_path)
    if target_name in names:
        return target_name

    matches = [name for name in names if name.endswith(target_name)]
    if len(matches) == 1:
        return matches[0]
    elif len(matches) > 1:
        raise ValueError(f"Multiple matches found for {target_name}: {matches}")
    else:
        raise FileNotFoundError(f"Could not find {target_name} inside zip.")

def read_cmapss_from_zip(zip_path, filename):
    member_path = resolve_member_path(zip_path, filename)
    with zipfile.ZipFile(zip_path, "r") as z:
        with z.open(member_path) as f:
            df = pd.read_csv(f, sep=r"\s+", header=None)
    return df

train_df = read_cmapss_from_zip(CFG.zip_path, f"train_{CFG.subset}.txt")
test_df = read_cmapss_from_zip(CFG.zip_path, f"test_{CFG.subset}.txt")
rul_df = read_cmapss_from_zip(CFG.zip_path, f"RUL_{CFG.subset}.txt")

columns = (
    ["unit", "cycle"] +
    [f"setting_{i}" for i in range(1, 4)] +
    [f"sensor_{i}" for i in range(1, 22)]
)

train_df.columns = columns
test_df.columns = columns
rul_df.columns = ["RUL"]

print("train_df shape:", train_df.shape)
print("test_df shape:", test_df.shape)
print("rul_df shape:", rul_df.shape)
# Out:
# train_df shape: (20631, 26)
# test_df shape: (13096, 26)
# rul_df shape: (100, 1)

# %% [markdown]
# Cell 5 — Preprocessing

# %%
RAW_FEATURE_COLS = [f"setting_{i}" for i in range(1, 4)] + [f"sensor_{i}" for i in range(1, 22)]

# compute train RUL
max_cycle = train_df.groupby("unit")["cycle"].max().reset_index()
max_cycle.columns = ["unit", "max_cycle"]
train_df = train_df.merge(max_cycle, on="unit")
train_df["RUL"] = train_df["max_cycle"] - train_df["cycle"]
train_df.drop(columns=["max_cycle"], inplace=True)

# RUL clipping
train_df["RUL"] = train_df["RUL"].clip(upper=CFG.rul_clip)

# engine-level split
all_units = sorted(train_df["unit"].unique())
rng = np.random.RandomState(CFG.random_seed)
rng.shuffle(all_units)

split_idx = int(CFG.train_ratio * len(all_units))
train_units = all_units[:split_idx]
val_units = all_units[split_idx:]

train_split_df = train_df[train_df["unit"].isin(train_units)].copy()
val_split_df = train_df[train_df["unit"].isin(val_units)].copy()

print("Train engines:", len(train_units))
print("Val engines:", len(val_units))

# remove near-zero variance features
feature_var = train_split_df[RAW_FEATURE_COLS].var()
feature_cols = feature_var[feature_var > 1e-8].index.tolist()
dropped_cols = [c for c in RAW_FEATURE_COLS if c not in feature_cols]

print("Selected features:", len(feature_cols))
print("Dropped features:", dropped_cols)

# standardization
scaler = StandardScaler()
train_split_df[feature_cols] = scaler.fit_transform(train_split_df[feature_cols])
val_split_df[feature_cols] = scaler.transform(val_split_df[feature_cols])
test_df[feature_cols] = scaler.transform(test_df[feature_cols])
# Out:
# Train engines: 80
# Val engines: 20
# Selected features: 17
# Dropped features: ['setting_3', 'sensor_1', 'sensor_5', 'sensor_10', 'sensor_16', 'sensor_18', 'sensor_19']

# %% [markdown]
# Cell 6 — Build Sequences

# %%
def build_train_sequences(df, feature_cols, target_col, window_size):
    X_list, y_list = [], []

    for unit_id in sorted(df["unit"].unique()):
        unit_df = df[df["unit"] == unit_id].sort_values("cycle")
        features = unit_df[feature_cols].values
        targets = unit_df[target_col].values

        if len(unit_df) < window_size:
            continue

        for i in range(len(unit_df) - window_size + 1):
            X_window = features[i:i + window_size]
            y_target = targets[i + window_size - 1]
            X_list.append(X_window)
            y_list.append(y_target)

    X = np.array(X_list, dtype=np.float32)
    y = np.array(y_list, dtype=np.float32)
    return X, y

def build_test_sequences(test_df, rul_df, feature_cols, window_size):
    X_list, y_list = [], []

    for i, unit_id in enumerate(sorted(test_df["unit"].unique())):
        unit_df = test_df[test_df["unit"] == unit_id].sort_values("cycle")
        features = unit_df[feature_cols].values

        if len(features) < window_size:
            pad_len = window_size - len(features)
            pad = np.repeat(features[0:1], pad_len, axis=0)
            features = np.vstack([pad, features])

        X_window = features[-window_size:]
        y_target = min(float(rul_df.iloc[i]["RUL"]), CFG.rul_clip)

        X_list.append(X_window)
        y_list.append(y_target)

    X = np.array(X_list, dtype=np.float32)
    y = np.array(y_list, dtype=np.float32)
    return X, y

X_train, y_train = build_train_sequences(train_split_df, feature_cols, "RUL", CFG.window_size)
X_val, y_val = build_train_sequences(val_split_df, feature_cols, "RUL", CFG.window_size)
X_test, y_test = build_test_sequences(test_df, rul_df, feature_cols, CFG.window_size)

print("Train:", X_train.shape, y_train.shape)
print("Val:  ", X_val.shape, y_val.shape)
print("Test: ", X_test.shape, y_test.shape)
# Out:
# Train: (14020, 30, 17) (14020,)
# Val:   (3711, 30, 17) (3711,)
# Test:  (100, 30, 17) (100,)

# %% [markdown]
# Cell 7 — Dataset / Dataloader

# %%
class CMAPSSDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

train_loader = DataLoader(CMAPSSDataset(X_train, y_train), batch_size=CFG.batch_size, shuffle=True)
val_loader = DataLoader(CMAPSSDataset(X_val, y_val), batch_size=CFG.batch_size, shuffle=False)
test_loader = DataLoader(CMAPSSDataset(X_test, y_test), batch_size=CFG.batch_size, shuffle=False)

# %% [markdown]
# Cell 8 — Metrics

# %%
def rmse_score(y_true, y_pred):
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))

def phm_score(y_true, y_pred):
    d = y_pred - y_true
    score = 0.0
    for di in d:
        if di < 0:
            score += np.exp(-di / 13.0) - 1.0
        else:
            score += np.exp(di / 10.0) - 1.0
    return float(score)

# %% [markdown]
# Cell 9 — Models

# %%
class LSTMRegressor(nn.Module):
    def __init__(self, input_size, hidden_size=128, num_layers=1, dropout=0.2):
        super().__init__()
        lstm_dropout = dropout if num_layers > 1 else 0.0
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            dropout=lstm_dropout,
            batch_first=True
        )
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)              # [B, T, H]
        last_out = out[:, -1, :]           # [B, H]
        last_out = self.dropout(last_out)
        y_hat = self.fc(last_out)          # [B, 1]
        return y_hat.squeeze(1)


class DCNNRegressor(nn.Module):
    """
    DCNN for C-MAPSS RUL prediction
    More paper-like version:
    - 5 temporal conv layers
    - no pooling
    - flatten + fully connected layers
    """
    def __init__(self, input_size, window_size, num_filters=32, fc_units=100, dropout=0.5):
        super().__init__()

        self.window_size = window_size
        self.num_filters = num_filters

        # Input after transpose: [B, F, T]
        self.conv1 = nn.Conv1d(input_size, num_filters, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(num_filters, num_filters, kernel_size=3, padding=1)
        self.conv3 = nn.Conv1d(num_filters, num_filters, kernel_size=3, padding=1)
        self.conv4 = nn.Conv1d(num_filters, num_filters, kernel_size=3, padding=1)
        self.conv5 = nn.Conv1d(num_filters, num_filters, kernel_size=3, padding=1)

        self.act = nn.ReLU()
        self.dropout = nn.Dropout(dropout)

        self.fc1 = nn.Linear(num_filters * window_size, fc_units)
        self.fc2 = nn.Linear(fc_units, 1)

        self._init_weights()

    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, (nn.Conv1d, nn.Linear)):
                nn.init.xavier_normal_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

    def forward(self, x):
        x = x.transpose(1, 2)

        x = self.act(self.conv1(x))
        x = self.act(self.conv2(x))
        x = self.act(self.conv3(x))
        x = self.act(self.conv4(x))
        x = self.act(self.conv5(x))

        # flatten instead of global average pooling
        x = x.reshape(x.size(0), -1)

        x = self.dropout(x)
        x = self.act(self.fc1(x))
        y_hat = self.fc2(x)

        return y_hat.squeeze(1)

# %% [markdown]
# Cell 10 — Train / Evaluate Functions

# %%
def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    total_loss = 0.0

    for X_batch, y_batch in loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()
        preds = model(X_batch)
        loss = criterion(preds, y_batch)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5.0)
        optimizer.step()

        total_loss += loss.item() * X_batch.size(0)

    return total_loss / len(loader.dataset)


@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    all_preds, all_targets = [], []

    for X_batch, y_batch in loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        preds = model(X_batch)
        loss = criterion(preds, y_batch)

        total_loss += loss.item() * X_batch.size(0)
        all_preds.append(preds.cpu().numpy())
        all_targets.append(y_batch.cpu().numpy())

    avg_loss = total_loss / len(loader.dataset)
    all_preds = np.concatenate(all_preds)
    all_targets = np.concatenate(all_targets)

    return {
        "loss": avg_loss,
        "rmse": rmse_score(all_targets, all_preds),
        "mae": float(mean_absolute_error(all_targets, all_preds)),
        "phm": phm_score(all_targets, all_preds),
        "preds": all_preds,
        "targets": all_targets
    }


def fit_model(model, train_loader, val_loader, cfg):
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=cfg.lr, weight_decay=cfg.weight_decay)

    history = {
        "train_loss": [],
        "val_loss": [],
        "val_rmse": []
    }

    best_val_rmse = float("inf")
    best_epoch = -1
    best_state = None
    epochs_no_improve = 0

    for epoch in range(1, cfg.num_epochs + 1):
        train_loss = train_one_epoch(model, train_loader, criterion, optimizer, cfg.device)
        val_metrics = evaluate(model, val_loader, criterion, cfg.device)

        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_metrics["loss"])
        history["val_rmse"].append(val_metrics["rmse"])

        print(
            f"Epoch {epoch:03d} | "
            f"Train Loss: {train_loss:.4f} | "
            f"Val Loss: {val_metrics['loss']:.4f} | "
            f"Val RMSE: {val_metrics['rmse']:.4f}"
        )

        if val_metrics["rmse"] < best_val_rmse:
            best_val_rmse = val_metrics["rmse"]
            best_epoch = epoch
            best_state = copy.deepcopy(model.state_dict())
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= cfg.patience:
            print("Early stopping triggered.")
            break

    model.load_state_dict(best_state)
    return model, history, best_epoch

# %% [markdown]
# Cell 11 — Run One Model

# %%
def run_model(model_name, cfg):
    set_seed(cfg.random_seed)

    if model_name == "LSTM":
        model = LSTMRegressor(
            input_size=len(feature_cols),
            hidden_size=cfg.hidden_size,
            num_layers=cfg.num_layers,
            dropout=cfg.lstm_dropout
        ).to(cfg.device)

    elif model_name == "DCNN":
        model = DCNNRegressor(
            input_size=len(feature_cols),
            window_size=cfg.window_size,
            num_filters=cfg.dcnn_num_filters,
            fc_units=cfg.dcnn_fc_units,
            dropout=cfg.dcnn_dropout
        ).to(cfg.device)

    else:
        raise ValueError("Unknown model name")

    print(model)

    model, history, best_epoch = fit_model(model, train_loader, val_loader, cfg)

    criterion = nn.MSELoss()
    val_metrics = evaluate(model, val_loader, criterion, cfg.device)
    test_metrics = evaluate(model, test_loader, criterion, cfg.device)

    summary = {
        "model": model_name,
        "best_epoch": best_epoch,
        "val_rmse": val_metrics["rmse"],
        "val_mae": val_metrics["mae"],
        "val_phm": val_metrics["phm"],
        "test_rmse": test_metrics["rmse"],
        "test_mae": test_metrics["mae"],
        "test_phm": test_metrics["phm"],
    }
    return model, history, summary, test_metrics

# %% [markdown]
# Cell 12 — Run Main Comparison

# %%
lstm_model, lstm_history, lstm_summary, lstm_test = run_model("LSTM", CFG)

dcnn_model, dcnn_history, dcnn_summary, dcnn_test = run_model("DCNN", CFG)

torch.save(lstm_model.state_dict(), "checkpoints/lstm_model.pt")
torch.save(dcnn_model.state_dict(), "checkpoints/dcnn_model.pt")

main_df = pd.DataFrame(
    [lstm_summary, dcnn_summary]
).sort_values("test_rmse").reset_index(drop=True)

main_df
# Out:
# LSTMRegressor(
#   (lstm): LSTM(17, 128, batch_first=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=128, out_features=1, bias=True)
# )
# Epoch 001 | Train Loss: 6670.4586 | Val Loss: 5827.0622 | Val RMSE: 76.3352
# Epoch 002 | Train Loss: 4708.4602 | Val Loss: 4198.8208 | Val RMSE: 64.7983
# Epoch 003 | Train Loss: 3320.0584 | Val Loss: 2879.2278 | Val RMSE: 53.6584
# Epoch 004 | Train Loss: 2211.4484 | Val Loss: 1904.0031 | Val RMSE: 43.6349
# Epoch 005 | Train Loss: 1462.8344 | Val Loss: 1294.5048 | Val RMSE: 35.9792
# Epoch 006 | Train Loss: 1033.8339 | Val Loss: 964.7179 | Val RMSE: 31.0599
# Epoch 007 | Train Loss: 757.8120 | Val Loss: 719.3289 | Val RMSE: 26.8203
# Epoch 008 | Train Loss: 593.8372 | Val Loss: 582.3455 | Val RMSE: 24.1318
# Epoch 009 | Train Loss: 479.2408 | Val Loss: 489.4451 | Val RMSE: 22.1234
# Epoch 010 | Train Loss: 415.3725 | Val Loss: 442.4240 | Val RMSE: 21.0339
# Epoch 011 | Train Loss: 354.1500 | Val Loss: 390.6033 | Val RMSE: 19.7637
# Epoch 012 | Train Loss: 310.7621 | Val Loss: 385.1355 | Val RMSE: 19.6249
# Epoch 013 | Train Loss: 270.8624 | Val Loss: 308.1565 | Val RMSE: 17.5544
# Epoch 014 | Train Loss: 244.9162 | Val Loss: 326.9093 | Val RMSE: 18.0806
# Epoch 015 | Train Loss: 236.2957 | Val Loss: 308.3870 | Val RMSE: 17.5610
# Epoch 016 | Train Loss: 214.2427 | Val Loss: 260.7375 | Val RMSE: 16.1474
# Epoch 017 | Train Loss: 193.9901 | Val Loss: 258.9462 | Val RMSE: 16.0918
# Epoch 018 | Train Loss: 205.0039 | Val Loss: 240.3354 | Val RMSE: 15.5028
# Epoch 019 | Train Loss: 183.6265 | Val Loss: 240.7858 | Val RMSE: 15.5173
# Epoch 020 | Train Loss: 167.6095 | Val Loss: 240.2709 | Val RMSE: 15.5007
# Epoch 021 | Train Loss: 165.8057 | Val Loss: 226.5748 | Val RMSE: 15.0524
# Epoch 022 | Train Loss: 155.9765 | Val Loss: 220.7409 | Val RMSE: 14.8574
# Epoch 023 | Train Loss: 151.8538 | Val Loss: 209.2187 | Val RMSE: 14.4644
# Epoch 024 | Train Loss: 145.1577 | Val Loss: 222.2822 | Val RMSE: 14.9091
# Epoch 025 | Train Loss: 143.6470 | Val Loss: 213.8658 | Val RMSE: 14.6242
# Epoch 026 | Train Loss: 143.2410 | Val Loss: 213.0077 | Val RMSE: 14.5948
# Epoch 027 | Train Loss: 139.4254 | Val Loss: 200.0086 | Val RMSE: 14.1424
# Epoch 028 | Train Loss: 135.1789 | Val Loss: 220.6943 | Val RMSE: 14.8558
# Epoch 029 | Train Loss: 134.5779 | Val Loss: 209.6952 | Val RMSE: 14.4809
# Epoch 030 | Train Loss: 129.9047 | Val Loss: 212.7268 | Val RMSE: 14.5852
# Epoch 031 | Train Loss: 121.3995 | Val Loss: 215.7004 | Val RMSE: 14.6867
# Epoch 032 | Train Loss: 115.6159 | Val Loss: 234.0244 | Val RMSE: 15.2979
# Epoch 033 | Train Loss: 113.3773 | Val Loss: 215.8694 | Val RMSE: 14.6925
# Epoch 034 | Train Loss: 109.3527 | Val Loss: 219.2998 | Val RMSE: 14.8088
# Epoch 035 | Train Loss: 105.0291 | Val Loss: 232.3530 | Val RMSE: 15.2431
# Epoch 036 | Train Loss: 105.8894 | Val Loss: 199.4630 | Val RMSE: 14.1231
# Epoch 037 | Train Loss: 101.2230 | Val Loss: 223.3463 | Val RMSE: 14.9448
# Epoch 038 | Train Loss: 95.9199 | Val Loss: 226.7865 | Val RMSE: 15.0594
# Epoch 039 | Train Loss: 94.4851 | Val Loss: 217.5674 | Val RMSE: 14.7502
# Epoch 040 | Train Loss: 93.6883 | Val Loss: 254.7324 | Val RMSE: 15.9603
# Epoch 041 | Train Loss: 90.9469 | Val Loss: 227.4406 | Val RMSE: 15.0811
# Epoch 042 | Train Loss: 85.8988 | Val Loss: 228.8614 | Val RMSE: 15.1282
# Epoch 043 | Train Loss: 84.7571 | Val Loss: 244.0433 | Val RMSE: 15.6219
# Epoch 044 | Train Loss: 78.8721 | Val Loss: 229.8810 | Val RMSE: 15.1618
# Epoch 045 | Train Loss: 76.3037 | Val Loss: 238.2087 | Val RMSE: 15.4340
# Epoch 046 | Train Loss: 74.4858 | Val Loss: 240.6551 | Val RMSE: 15.5131
# Early stopping triggered.
# DCNNRegressor(
#   (conv1): Conv1d(17, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (conv2): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (conv3): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (conv4): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (conv5): Conv1d(32, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (act): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc1): Linear(in_features=960, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=1, bias=True)
# )
# Epoch 001 | Train Loss: 1704.2273 | Val Loss: 471.8108 | Val RMSE: 21.7212
# Epoch 002 | Train Loss: 371.9263 | Val Loss: 432.0751 | Val RMSE: 20.7864
# Epoch 003 | Train Loss: 264.3939 | Val Loss: 342.4146 | Val RMSE: 18.5044
# Epoch 004 | Train Loss: 192.6410 | Val Loss: 370.0979 | Val RMSE: 19.2379
# Epoch 005 | Train Loss: 127.7406 | Val Loss: 385.4130 | Val RMSE: 19.6319
# Epoch 006 | Train Loss: 116.4035 | Val Loss: 369.5834 | Val RMSE: 19.2246
# Epoch 007 | Train Loss: 78.6799 | Val Loss: 390.6188 | Val RMSE: 19.7641
# Epoch 008 | Train Loss: 62.9842 | Val Loss: 447.0187 | Val RMSE: 21.1428
# Epoch 009 | Train Loss: 55.8956 | Val Loss: 402.1078 | Val RMSE: 20.0526
# Epoch 010 | Train Loss: 48.4099 | Val Loss: 434.3652 | Val RMSE: 20.8414
# Epoch 011 | Train Loss: 50.2243 | Val Loss: 429.0055 | Val RMSE: 20.7124
# Epoch 012 | Train Loss: 49.4722 | Val Loss: 477.6746 | Val RMSE: 21.8558
# Epoch 013 | Train Loss: 34.9073 | Val Loss: 454.9620 | Val RMSE: 21.3298
# Early stopping triggered.
#   model  best_epoch   val_rmse    val_mae       val_phm  test_rmse   test_mae  \
# 0  LSTM          36  14.123137   9.739722  18687.937500  13.920273  10.659898
# 1  DCNN           3  18.504448  14.960047  19184.832031  17.045796  13.160506
#
#      test_phm
# 0  315.494110
# 1  487.463745

# %% [markdown]
# Cell 12.5 — DCNN Ablation Study

# %%
# Cell 12.5 — DCNN Ablation Study

ablation_results = []
# 1) Initial DCNN

class InitialDCNNRegressor(nn.Module):
    """
    Traditional CNN-style architecture
    - 2 temporal conv layers
    - max pooling
    - global average pooling
    - fully connected regression head
    """

    def __init__(self, input_size, window_size, num_filters=32, fc_units=100, dropout=0.2):
        super().__init__()

        self.window_size = window_size
        self.num_filters = num_filters

        # Input after transpose: [B, F, T]
        self.conv1 = nn.Conv1d(input_size, num_filters, kernel_size=3, padding=1)
        self.conv2 = nn.Conv1d(num_filters, num_filters, kernel_size=3, padding=1)

        self.pool = nn.MaxPool1d(kernel_size=2)
        self.act = nn.ReLU()
        self.dropout = nn.Dropout(dropout)

        # after global average pooling: [B, num_filters]
        self.fc1 = nn.Linear(num_filters, fc_units)
        self.fc2 = nn.Linear(fc_units, 1)

    def forward(self, x):
        # x: [B, T, F] -> [B, F, T]
        x = x.transpose(1, 2)

        x = self.act(self.conv1(x))
        x = self.pool(x)

        x = self.act(self.conv2(x))
        x = self.pool(x)

        # global average pooling: [B, num_filters, T'] -> [B, num_filters]
        x = x.mean(dim=2)

        x = self.dropout(x)
        x = self.act(self.fc1(x))
        y_hat = self.fc2(x)

        return y_hat.squeeze(1)

# helper function

def run_custom_model(model, model_name):

    model = model.to(CFG.device)

    model, history, best_epoch = fit_model(
        model,
        train_loader,
        val_loader,
        CFG
    )

    criterion = nn.MSELoss()

    test_metrics = evaluate(
        model,
        test_loader,
        criterion,
        CFG.device
    )

    ablation_results.append({
        "model": model_name,
        "test_rmse": test_metrics["rmse"],
        "test_phm": test_metrics["phm"]
    })

    return history

# 2) Run Initial DCNN

set_seed(CFG.random_seed)

initial_model = InitialDCNNRegressor(
    input_size=len(feature_cols),
    window_size=CFG.window_size,
    num_filters=CFG.dcnn_num_filters,
    fc_units=CFG.dcnn_fc_units,
    dropout=0.2
)

initial_history = run_custom_model(
    initial_model,
    "DCNN(inital)"
)

# 3) Run Improved DCNN

set_seed(CFG.random_seed)

improved_model = DCNNRegressor(
    input_size=len(feature_cols),
    window_size=CFG.window_size,
    num_filters=CFG.dcnn_num_filters,
    fc_units=CFG.dcnn_fc_units,
    dropout=0.2
)

improved_history = run_custom_model(
    improved_model,
    "DCNN (improved)"
)

# 4) Run Dropout = 0.3

set_seed(CFG.random_seed)

drop03_model = DCNNRegressor(
    input_size=len(feature_cols),
    window_size=CFG.window_size,
    num_filters=CFG.dcnn_num_filters,
    fc_units=CFG.dcnn_fc_units,
    dropout=0.3
)

drop03_history = run_custom_model(
    drop03_model,
    "DCNN (dropout=0.3)"
)

# 5) Run Dropout = 0.5

set_seed(CFG.random_seed)

drop05_model = DCNNRegressor(
    input_size=len(feature_cols),
    window_size=CFG.window_size,
    num_filters=CFG.dcnn_num_filters,
    fc_units=CFG.dcnn_fc_units,
    dropout=0.5
)

drop05_history = run_custom_model(
    drop05_model,
    "DCNN (dropout=0.5)"
)

# Final Table

ablation_df = pd.DataFrame(ablation_results)
ablation_df
# Out:
# Epoch 001 | Train Loss: 3926.3935 | Val Loss: 835.2415 | Val RMSE: 28.9005
# Epoch 002 | Train Loss: 672.2474 | Val Loss: 578.7551 | Val RMSE: 24.0573
# Epoch 003 | Train Loss: 602.5852 | Val Loss: 576.7136 | Val RMSE: 24.0149
# Epoch 004 | Train Loss: 571.0209 | Val Loss: 553.7280 | Val RMSE: 23.5314
# Epoch 005 | Train Loss: 527.3158 | Val Loss: 489.0153 | Val RMSE: 22.1137
# Epoch 006 | Train Loss: 481.3321 | Val Loss: 482.2368 | Val RMSE: 21.9599
# Epoch 007 | Train Loss: 455.2068 | Val Loss: 470.8216 | Val RMSE: 21.6984
# Epoch 008 | Train Loss: 434.2827 | Val Loss: 459.5482 | Val RMSE: 21.4371
# Epoch 009 | Train Loss: 420.4868 | Val Loss: 459.2327 | Val RMSE: 21.4297
# Epoch 010 | Train Loss: 397.6891 | Val Loss: 454.6539 | Val RMSE: 21.3226
# Epoch 011 | Train Loss: 387.3046 | Val Loss: 478.6342 | Val RMSE: 21.8777
# Epoch 012 | Train Loss: 359.2218 | Val Loss: 469.2905 | Val RMSE: 21.6631
# Epoch 013 | Train Loss: 340.3308 | Val Loss: 465.5309 | Val RMSE: 21.5762
# Epoch 014 | Train Loss: 310.2326 | Val Loss: 465.2253 | Val RMSE: 21.5691
# Epoch 015 | Train Loss: 285.4568 | Val Loss: 485.6245 | Val RMSE: 22.0369
# Epoch 016 | Train Loss: 263.3132 | Val Loss: 535.4531 | Val RMSE: 23.1399
# Epoch 017 | Train Loss: 243.1009 | Val Loss: 512.2320 | Val RMSE: 22.6325
# Epoch 018 | Train Loss: 225.2253 | Val Loss: 506.1372 | Val RMSE: 22.4975
# Epoch 019 | Train Loss: 215.3035 | Val Loss: 546.9946 | Val RMSE: 23.3879
# Epoch 020 | Train Loss: 206.8881 | Val Loss: 503.5206 | Val RMSE: 22.4393
# Early stopping triggered.
# Epoch 001 | Train Loss: 1704.2273 | Val Loss: 471.8108 | Val RMSE: 21.7212
# Epoch 002 | Train Loss: 371.9263 | Val Loss: 432.0751 | Val RMSE: 20.7864
# Epoch 003 | Train Loss: 264.3939 | Val Loss: 342.4146 | Val RMSE: 18.5044
# Epoch 004 | Train Loss: 192.6410 | Val Loss: 370.0979 | Val RMSE: 19.2379
# Epoch 005 | Train Loss: 127.7406 | Val Loss: 385.4130 | Val RMSE: 19.6319
# Epoch 006 | Train Loss: 116.4035 | Val Loss: 369.5834 | Val RMSE: 19.2246
# Epoch 007 | Train Loss: 78.6799 | Val Loss: 390.6188 | Val RMSE: 19.7641
# Epoch 008 | Train Loss: 62.9842 | Val Loss: 447.0187 | Val RMSE: 21.1428
# Epoch 009 | Train Loss: 55.8956 | Val Loss: 402.1078 | Val RMSE: 20.0526
# Epoch 010 | Train Loss: 48.4099 | Val Loss: 434.3652 | Val RMSE: 20.8414
# Epoch 011 | Train Loss: 50.2243 | Val Loss: 429.0055 | Val RMSE: 20.7124
# Epoch 012 | Train Loss: 49.4722 | Val Loss: 477.6746 | Val RMSE: 21.8558
# Epoch 013 | Train Loss: 34.9073 | Val Loss: 454.9620 | Val RMSE: 21.3298
# Early stopping triggered.
# Epoch 001 | Train Loss: 1706.9997 | Val Loss: 523.6656 | Val RMSE: 22.8837
# Epoch 002 | Train Loss: 401.1584 | Val Loss: 481.3546 | Val RMSE: 21.9398
# Epoch 003 | Train Loss: 266.8173 | Val Loss: 381.3216 | Val RMSE: 19.5275
# Epoch 004 | Train Loss: 171.7050 | Val Loss: 369.2799 | Val RMSE: 19.2167
# Epoch 005 | Train Loss: 125.9286 | Val Loss: 394.0822 | Val RMSE: 19.8515
# Epoch 006 | Train Loss: 92.8022 | Val Loss: 471.6413 | Val RMSE: 21.7173
# Epoch 007 | Train Loss: 81.7583 | Val Loss: 415.2965 | Val RMSE: 20.3788
# Epoch 008 | Train Loss: 66.8097 | Val Loss: 437.0280 | Val RMSE: 20.9052
# Epoch 009 | Train Loss: 49.4263 | Val Loss: 471.1306 | Val RMSE: 21.7055
# Epoch 010 | Train Loss: 46.2207 | Val Loss: 518.8261 | Val RMSE: 22.7778
# Epoch 011 | Train Loss: 40.6805 | Val Loss: 559.2710 | Val RMSE: 23.6489
# Epoch 012 | Train Loss: 32.9398 | Val Loss: 509.2797 | Val RMSE: 22.5672
# Epoch 013 | Train Loss: 39.6026 | Val Loss: 486.6485 | Val RMSE: 22.0601
# Epoch 014 | Train Loss: 36.7856 | Val Loss: 531.3923 | Val RMSE: 23.0519
# Early stopping triggered.
# Epoch 001 | Train Loss: 1720.0524 | Val Loss: 529.7707 | Val RMSE: 23.0167
# Epoch 002 | Train Loss: 389.0267 | Val Loss: 438.9244 | Val RMSE: 20.9505
# Epoch 003 | Train Loss: 269.9577 | Val Loss: 393.1822 | Val RMSE: 19.8288
# Epoch 004 | Train Loss: 189.1564 | Val Loss: 443.7294 | Val RMSE: 21.0649
# Epoch 005 | Train Loss: 136.7065 | Val Loss: 423.7435 | Val RMSE: 20.5850
# Epoch 006 | Train Loss: 106.5150 | Val Loss: 453.8981 | Val RMSE: 21.3049
# Epoch 007 | Train Loss: 80.0426 | Val Loss: 465.2224 | Val RMSE: 21.5690
# Epoch 008 | Train Loss: 70.4806 | Val Loss: 476.3599 | Val RMSE: 21.8257
# Epoch 009 | Train Loss: 61.8418 | Val Loss: 471.6188 | Val RMSE: 21.7168
# Epoch 010 | Train Loss: 80.2374 | Val Loss: 550.6262 | Val RMSE: 23.4654
# Epoch 011 | Train Loss: 50.9140 | Val Loss: 518.0738 | Val RMSE: 22.7612
# Epoch 012 | Train Loss: 56.6905 | Val Loss: 497.1563 | Val RMSE: 22.2970
# Epoch 013 | Train Loss: 42.8113 | Val Loss: 549.5840 | Val RMSE: 23.4432
# Early stopping triggered.
#                 model  test_rmse     test_phm
# 0        DCNN(inital)  20.037256  1585.873779
# 1     DCNN (improved)  17.045796   487.463745
# 2  DCNN (dropout=0.3)  17.993994   570.393677
# 3  DCNN (dropout=0.5)  18.226722   597.390625

# %% [markdown]
# Cell 13 — Graph 1: RMSE Comparison

# %%
plt.figure(figsize=(6, 4))
plt.bar(main_df["model"], main_df["test_rmse"])
plt.xlabel("Model")
plt.ylabel("Test RMSE")
plt.title("RMSE Comparison on FD001")
plt.grid(axis="y")
plt.show()

# %% [markdown]
# Cell 14 — Graph 2: PHM Comparison

# %%
plt.figure(figsize=(6, 4))
plt.bar(main_df["model"], main_df["test_phm"])
plt.xlabel("Model")
plt.ylabel("Test PHM Score")
plt.title("PHM Score Comparison on FD001")
plt.grid(axis="y")
plt.show()

# %% [markdown]
# Cell 15 — Graph 3: Training Curves for Both Models

# %%
# 1) Train / Val Loss comparison
plt.figure(figsize=(8, 5))
plt.plot(lstm_history["train_loss"], label="LSTM Train Loss")
plt.plot(lstm_history["val_loss"], label="LSTM Val Loss")
plt.plot(dcnn_history["train_loss"], label="DCNN Train Loss")
plt.plot(dcnn_history["val_loss"], label="DCNN Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss: LSTM vs DCNN")
plt.legend()
plt.grid(True)
plt.show()

# 2) Validation RMSE comparison
plt.figure(figsize=(8, 5))
plt.plot(lstm_history["val_rmse"], label="LSTM Val RMSE")
plt.plot(dcnn_history["val_rmse"], label="DCNN Val RMSE")
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.title("Validation RMSE: LSTM vs DCNN")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Cell 16 — Final Print

# %%
print(main_df)
# Out:
#   model  best_epoch   val_rmse    val_mae       val_phm  test_rmse   test_mae  \
# 0  LSTM          36  14.123137   9.739722  18687.937500  13.920273  10.659898
# 1  DCNN           3  18.504448  14.960047  19184.832031  17.045796  13.160506
#
#      test_phm
# 0  315.494110
# 1  487.463745
