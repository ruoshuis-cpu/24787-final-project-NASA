# %%
import torch

# %%
torch.load("checkpoints/lstm_model.pt")
torch.load("checkpoints/dcnn_model.pt")
# Out:
# OrderedDict([('conv1.weight',
#               tensor([[[ 0.0397,  0.1218, -0.0523],
#                        [ 0.0581,  0.0179, -0.0398],
#                        [-0.0088, -0.1313, -0.1697],
#                        ...,
#                        [ 0.0453,  0.0979,  0.0705],
#                        [ 0.0291,  0.0898,  0.0771],
#                        [-0.0406,  0.0355, -0.1308]],
#
#                       [[-0.0030, -0.1603, -0.2653],
#                        [-0.1782, -0.0849, -0.0169],
#                        [-0.0855, -0.1297,  0.0499],
#                        ...,
#                        [-0.1768, -0.1201,  0.1249],
#                        [ 0.0981,  0.1172, -0.3036],
#                        [ 0.2612,  0.1291, -0.2641]],
#
#                       [[ 0.0155, -0.0843, -0.0314],
#                        [ 0.0283, -0.0888, -0.1883],
#                        [-0.0370, -0.0611,  0.0894],
#                        ...,
#                        [-0.0716,  0.0013,  0.1855],
# ...
